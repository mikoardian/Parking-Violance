#   inflating: Melanggar-JPG/test-74.jpg
#   inflating: Melanggar-JPG/test-68.jpg
#   inflating: Melanggar-JPG/test-23.jpg
#   inflating: Melanggar-JPG/test-27.jpg
#   inflating: Melanggar-JPG/test-42.jpg
#   inflating: Melanggar-JPG/test-25.jpg
#   inflating: Melanggar-JPG/test-15.jpg
#   inflating: Melanggar-JPG/test-70.jpg
#   inflating: Melanggar-JPG/test-29.jpg
#   inflating: Melanggar-JPG/test-71.jpg
#   inflating: Melanggar-JPG/test-41.jpg
#   inflating: Melanggar-JPG/test-14.jpg
#   inflating: Melanggar-JPG/test-35.jpg
#   inflating: Melanggar-JPG/test-21.jpg
#   inflating: Melanggar-JPG/test-17.jpg
#   inflating: Melanggar-JPG/test-34.jpg
#   inflating: Melanggar-JPG/test-30.jpg
#   inflating: Melanggar-JPG/test-19.jpg
#   inflating: Melanggar-JPG/test-13.jpg
#   inflating: Melanggar-JPG/test-144.jpg
#   inflating: Melanggar-JPG/test-22.jpg
#   inflating: Melanggar-JPG/test-26.jpg
#   inflating: Melanggar-JPG/test-16.jpg
#   inflating: Melanggar-JPG/test-24.jpg
#   inflating: Melanggar-JPG/test-20.jpg
#   inflating: Melanggar-JPG/test-77.jpg
#   inflating: Melanggar-JPG/test-18.jpg

# %%
# Kemudian kita load bagian list koordinatnya

import pandas as pd
ini = pd.read_excel('/content/drive/MyDrive/PELANGGAR-PARKIR/Melanggar-Anotasi.xlsx')
ini
# Out:
#        image_name label_name   x1   y1  xwidth  yheight  image_width  \
# 0     test-01.jpg      rambu  356    4     227      231          862
# 1     test-01.jpg      mobil  161  718     478      145          862
# 2     test-01.jpg      mobil  661  783     134       80          862
# 3     test-02.jpg      mobil  183  178     140      106          360
# 4     test-02.jpg      rambu   11   33     147      265          360
# ..            ...        ...  ...  ...     ...      ...          ...
# 263  test-146.jpg      rambu   64   27      42       52          177
# 264  test-147.jpg      rambu    1   12      95      114          274
# 265  test-148.jpg      rambu   68   92      81       82          246
# 266  test-149.jpg      rambu   27    1     192      158          371
# 267  test-150.jpg      rambu  127   57     141      176          512
#
#      image_height   x2   y2
# 0             863  583  235
# 1             863  639  863
# 2             863  795  863
# 3             360  323  284
# 4             360  158  298
# ..            ...  ...  ...
# 263           177  106   79
# 264           274   96  126
# 265           246  149  174
# 266           371  219  159
# 267           512  268  233
#
# [268 rows x 10 columns]

# %%
import pandas as pd

# Menentukan perbandingan ukuran baru dengan ukuran asli
width_ratio = 200 / ini['image_width']
height_ratio = 200 / ini['image_height']

# Mengubah nilai x1, y1, x2, dan y2 sesuai dengan perbandingan ukuran
ini["x1"] = ini["x1"] * width_ratio
ini["y1"] = ini["y1"] * height_ratio
ini["x2"] = ini["x2"] * width_ratio
ini["y2"] = ini["y2"] * height_ratio

# Menyimpan perubahan ke file anotasi
ini.to_csv("anotasi_mobil_resize200.csv", index=False)

# %%
# Filter the rows where label_name is "mobil"
ini = ini[ini["label_name"] == "mobil"]
ini = ini.drop(columns=["label_name","xwidth","yheight","image_width", "image_height"])
ini
# Out:
#        image_name          x1          y1          x2          y2
# 1     test-01.jpg   37.354988  166.396292  148.259861  200.000000
# 2     test-01.jpg  153.364269  181.460023  184.454756  200.000000
# 3     test-02.jpg  101.666667   98.888889  179.444444  157.777778
# 6     test-03.jpg   88.311688   96.440129  200.000000  194.822006
# 7     test-04.jpg   94.983278  105.333333  200.000000  186.666667
# ..            ...         ...         ...         ...         ...
# 219  test-114.jpg  180.178174   76.391982  200.000000  120.044543
# 224  test-118.jpg  161.971831  100.699301  200.000000  169.230769
# 226  test-119.jpg   55.506608  105.077263   70.044053  117.439294
# 227  test-119.jpg   81.057269  105.960265   99.118943  119.205298
# 229  test-120.jpg   27.493261  169.230769  105.929919  200.000000
#
# [147 rows x 5 columns]

# %%
# Mengubah nilai x1, y1, x2, dan y2 menjadi integer
ini["x1"] = ini["x1"].round().astype(int)
ini["y1"] = ini["y1"].round().astype(int)
ini["x2"] = ini["x2"].round().astype(int)
ini["y2"] = ini["y2"].round().astype(int)

# %%
ini
# Out:
#        image_name   x1   y1   x2   y2
# 1     test-01.jpg   37  166  148  200
# 2     test-01.jpg  153  181  184  200
# 3     test-02.jpg  102   99  179  158
# 6     test-03.jpg   88   96  200  195
# 7     test-04.jpg   95  105  200  187
# ..            ...  ...  ...  ...  ...
# 219  test-114.jpg  180   76  200  120
# 224  test-118.jpg  162  101  200  169
# 226  test-119.jpg   56  105   70  117
# 227  test-119.jpg   81  106   99  119
# 229  test-120.jpg   27  169  106  200
#
# [147 rows x 5 columns]

# %%
import cv2
import matplotlib.pyplot as plt

lokasi = 0
gambar = cv2.imread("Melanggar-JPG/" + ini.values[lokasi,0])
gambar = cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB)
plt.imshow(gambar)

# %% [markdown]
# Karena foto di folder Melanggar-JPG masih berisikan semua foto, disini membuat folder baru "melanggar_mobil" yang hanya terdapat gambar mobil berdasarkan dataset "ini" untuk data Training

# %%
import os
import shutil
import pandas as pd

#Mencari nama file yang ada di dalam kolom "image_name"
files = ini["image_name"].tolist()

#Membuat folder baru, jika belum ada
if not os.path.exists("melanggar_mobil"):
    os.makedirs("melanggar_mobil")
#Memindahkan file yang ada di folder "Melanggar-jpg" ke folder baru, jika file tersebut ada di dalam kolom "image_name"
for file in os.listdir("Melanggar-JPG"):
    if file in files:
        os.rename("Melanggar-JPG/" + file, "melanggar_mobil/" + file)

# %%
import cv2
import os

path = "melanggar_mobil"
for file in os.listdir(path):
    # Load gambar
    img = cv2.imread(os.path.join(path, file))
    # Resize gambar
    img = cv2.resize(img, (200, 200))
    # Save gambar yang sudah di resize
    cv2.imwrite(os.path.join(path, file), img)

# %%
# Sekarang, mari kita pergunakan fungsi cv2.
lokasi = 0
gambar = cv2.imread("melanggar_mobil/" + ini.values[lokasi,0])
gambar = cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB)
gambar = cv2.rectangle(gambar, ini.values[lokasi,1:3], ini.values[lokasi,3:5], (255, 0, 0), 2)
plt.imshow(gambar)

# %% [markdown]
# ## Otak CNN
#
# Sekarang kita persiapkan otak CNN kita yang akan kita pergunakan untuk metrain agar dia dapat memprediksi di mana kira-kira lokasi koordinat objek tersebut berada.
#
# Yang membedakan adalah `activation` pada `Dense` yang paling terakhir, di sana kita akan menggunakan `sigmoid` dengan jumlah `4 Dense` agar variabel `[x1, y1, x2, y2]` bisa diikutkan ditraining pada bagian output.
#
# Satu lagi, karena ini merupakan kasus regresi, maka kita pastikan agar `loss` yang kita pergunakan adalah `mse`.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
model = Sequential()

model.add(Conv2D(8, (3, 3), input_shape=(200, 200, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(32, (3,3), activation="relu"))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3,3), activation="relu"))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(256, (3,3), activation="relu"))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(512, (3,3), activation="relu"))
model.add(MaxPooling2D(2, 2))
   

model.add(Flatten())
model.add(Dense(20, activation="relu"))

model.add(Dense(4, activation="sigmoid"))
model.compile(
    optimizer="adam",
    loss="mse"
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 32)        2336
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 512)         1180160
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 20)                10260
#
#  dense_1 (Dense)             (None, 4)                 84
#
# =================================================================
# Total params: 1,580,584
# Trainable params: 1,580,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Selanjutnya kita persiapkan datasetnya, dengan cara sebagai berikut.

# %%
import numpy as np
x = []
y = []

for info in ini.values:
    x.append(cv2.imread("melanggar_mobil/"+info[0])/255)
    y.append([info[1]/200, info[2]/200, info[3]/200, info[4]/200])

x = np.asarray(x)
y = np.asarray(y)

# %%
x.shape
# Out:
# (147, 200, 200, 3)

# %%
y.shape
# Out:
# (147, 4)

# %% [markdown]
# Baru kemudian kita train seperti biasa.

# %%
history = model.fit(x, y, batch_size=1, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 132/132 [==============================] - 9s 6ms/step - loss: 0.0639 - val_loss: 0.0526
# Epoch 2/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0532 - val_loss: 0.0697
# Epoch 3/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0498 - val_loss: 0.0729
# Epoch 4/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0498 - val_loss: 0.0600
# Epoch 5/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0475 - val_loss: 0.0642
# Epoch 6/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0478 - val_loss: 0.0650
# Epoch 7/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0461 - val_loss: 0.0666
# Epoch 8/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0439 - val_loss: 0.0583
# Epoch 9/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0416 - val_loss: 0.0688
# Epoch 10/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0405 - val_loss: 0.0675
# Epoch 11/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0373 - val_loss: 0.0679
# Epoch 12/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0364 - val_loss: 0.0607
# Epoch 13/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0365 - val_loss: 0.0764
# Epoch 14/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.0734
# Epoch 15/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0360 - val_loss: 0.0724
# Epoch 16/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0322 - val_loss: 0.0775
# Epoch 17/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0316 - val_loss: 0.0835
# Epoch 18/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0317 - val_loss: 0.0843
# Epoch 19/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0284 - val_loss: 0.0755
# Epoch 20/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0301 - val_loss: 0.0955
# Epoch 21/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0275 - val_loss: 0.0618
# Epoch 22/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0269 - val_loss: 0.0837
# Epoch 23/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0253 - val_loss: 0.0890
# Epoch 24/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0259 - val_loss: 0.0864
# Epoch 25/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0241 - val_loss: 0.0883
# Epoch 26/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0232 - val_loss: 0.0914
# Epoch 27/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0228 - val_loss: 0.0818
# Epoch 28/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0217 - val_loss: 0.0859
# Epoch 29/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0217 - val_loss: 0.0854
# Epoch 30/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0215 - val_loss: 0.0773
# Epoch 31/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0209 - val_loss: 0.0680
# Epoch 32/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0206 - val_loss: 0.0778
# Epoch 33/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0220 - val_loss: 0.0793
# Epoch 34/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0203 - val_loss: 0.0877
# Epoch 35/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.0863
# Epoch 36/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0206 - val_loss: 0.0951
# Epoch 37/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0197 - val_loss: 0.0823
# Epoch 38/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0200 - val_loss: 0.0812
# Epoch 39/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0201 - val_loss: 0.0831
# Epoch 40/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0207 - val_loss: 0.0806
# Epoch 41/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0202 - val_loss: 0.0848
# Epoch 42/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0194 - val_loss: 0.0849
# Epoch 43/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0190 - val_loss: 0.0819
# Epoch 44/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0186 - val_loss: 0.0787
# Epoch 45/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0188 - val_loss: 0.0804
# Epoch 46/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0187 - val_loss: 0.0826
# Epoch 47/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0190 - val_loss: 0.0819
# Epoch 48/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0191 - val_loss: 0.0800
# Epoch 49/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0188 - val_loss: 0.0851
# Epoch 50/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0192 - val_loss: 0.0754

# %%
# %matplotlib inline
import matplotlib.image as mpig
import matplotlib.pyplot as plt

loss         = history.history['loss']
val_loss     = history.history['val_loss']

epochs = range(len(loss))
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Training Validation Loss")
plt.title("Loss and Validation Loss of Model")
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# Setelah itu, mari kita coba test dengan memprediksi sebuah objek lingkaran pada file 10.jpg.

# %%
model.save_weights('Kipas_Angin_Fungsi_3_mobil.h5')

# %%
model.load_weights('/content/drive/MyDrive/PELANGGAR-PARKIR/Kipas_Angin_Fungsi_3_mobil.h5')

# %%
x_test = []
x_test.append(x[0])
#x_test.append(x[10])

x_test = np.asarray(x_test)
y_pred = model.predict(x_test)
y_pred = (y_pred)*200
y_pred = y_pred.astype(int)

y_pred
# Out:
# 1/1 [==============================] - 0s 99ms/step
# array([[101, 155, 182, 195]])

# %%
gambar = x[0].copy()
gambar = cv2.rectangle(gambar, y_pred[0][0:2], y_pred[0][2:4],(0,0,255),2)
plt.imshow(gambar)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
x_test = []
#x_test.append(x[0])
x_test.append(x[42])

x_test = np.asarray(x_test)
y_pred = model.predict(x_test)
y_pred = (y_pred)*200
y_pred = y_pred.astype(int)

y_pred
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[ 20,  74, 185, 171]])

# %%
gambar = x[42].copy()
gambar = cv2.rectangle(gambar, y_pred[0][0:2], y_pred[0][2:4],(0,0,255),2)
plt.imshow(gambar)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Tampak model kita sudah bisa melakukan deteksi walau masih belum terlalu presisi dalam menangkap objek lingkaran.
